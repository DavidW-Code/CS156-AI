# %% [markdown]
# # <b>CS156 (Introduction to AI), Spring 2021</b>
# # <u><b>Homework 6 submission</b></u>

# %% [markdown]
# ### Roster Name: David Wang
# ### Student ID: 012368967
# ### Email address: davidwangdn@gmail.com

# %% [markdown]
# ##  <u>References and sources </u>

# %% [markdown]
# Perceptron.Breast.ipynb

# %% [markdown]
# ##  <u>Solution</u>

# %% [markdown]
# #### Load libraries and set random number generator seed

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import plot_confusion_matrix

# %%
np.random.seed(42)

# %% [markdown]
# #### Code the solution

# %%
digits = load_digits()
X = digits.data.astype("float32")/255
Y = digits.target.astype("float32")
class_names = digits.target_names

# %%
for i in class_names:
    modified_Y = (Y == i).astype("int")
    X_train, X_test, Y_train, Y_test = train_test_split(X, modified_Y, test_size=0.2, random_state=0, stratify=Y)
    X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
    
    model = Perceptron(tol=1e-3, random_state=0)
    model.fit(X_train, Y_train)
    score = '{:.2f}'.format(model.score(X_test, Y_test))
    
    np.set_printoptions(precision=2)
    titles_options = [("Test set results for " + str(i) + " (" + str(score) + ")", None)]
    for title, normalize in titles_options:
        disp = plot_confusion_matrix(model, X_test, Y_test,
                                     display_labels=["Not " + str(i),i],
                                     cmap=plt.cm.Blues,
                                     normalize=normalize)
        disp.ax_.set_title(title)

    plt.show()
